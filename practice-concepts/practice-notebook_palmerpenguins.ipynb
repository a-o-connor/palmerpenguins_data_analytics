# %% [markdown]
# # Palmer Penguins
# **Author: A.O'Connor**
# **************
# This notebook contains my own analysis of the famous palmer penguins dataset. Palmer Penguins is a famous data set available on [github](https://allisonhorst.github.io/palmerpenguins/). It will be loaded into this notebook for data visualisation and exploration. It contains data from 344 penguins, collected at the Palmer Research Station in Antarctica.
# **************

# %% [markdown]
# ### Import Libraries
# The pandas library will be used in the interpretation and analysis of the data set.
# Matplotlib will be used for basic visualisation of the data.
# *********

# %%
# Install pandas 
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load the Palmer Penguins data set
# Load the raw csv file into the notebook
# ************************

# %%
# Load the penguins dataset using pandas
df = pd.read_csv ("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/penguins.csv")

# %% [markdown]
# ### View the data frame
# View the data frame
# Using pandas, extract the summary statistics of the data frame.
# ***********************

# %%
# View the data frame
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# ...

# %%
#Summary statistics of the data frame:
df.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %% [markdown]
# ### Indexing with Pandas
# Practice indexing the data frame
# *********

# %%
#View the first 4 rows
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %%
#View the second row:
#Use iloc
df.iloc[1]
# Out:
# species                 Adelie
# island               Torgersen
# bill_length_mm            39.5
# bill_depth_mm             17.4
# flipper_length_mm        186.0
# body_mass_g             3800.0
# sex                     FEMALE
# Name: 1, dtype: object

# %%
#Practice indexing 
#View the second row
df.iloc[1,]
# Out:
# species                 Adelie
# island               Torgersen
# bill_length_mm            39.5
# bill_depth_mm             17.4
# flipper_length_mm        186.0
# body_mass_g             3800.0
# sex                     FEMALE
# Name: 1, dtype: object

# %%
#Practice indexing 
#View the entry in the 2nd row for the 4th column:
df.iloc[1,3]
# Out:
# 17.4

# %%
#View the column with heading Sex
df["sex"]
# Out:
# 0        MALE
# 1      FEMALE
# 2      FEMALE
# 3         NaN
# 4      FEMALE
#         ...
# 339       NaN
# 340    FEMALE
# 341      MALE
# 342    FEMALE
# 343      MALE
# Name: sex, Length: 344, dtype: object

# %%
#Count  the number of each sex
df["sex"].value_counts()
# Out:
# sex
# MALE      168
# FEMALE    165
# Name: count, dtype: int64

# %%
#Practice indexing 
#View the 2nd, 3rd and 4th row of the data frame
df.iloc[[1,2,3]]
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
#
#    body_mass_g     sex
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN

# %%
#To view all rows in a particular column
#Use iloc[:,[]] to select all the rows
#Use [[]] to select the column (why???)


#View the second column
df.iloc[:,[1]]

#View the 2nd, 3rd and 4th column:
df.iloc[:,[1,2,3]]

df.iloc[1:3,[4,6]]
# Out:
#    flipper_length_mm     sex
# 1              186.0  FEMALE
# 2              195.0  FEMALE

# %%
#Practice indexing
df[df['bill_length_mm']>39]
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# 7    Adelie  Torgersen            39.2           19.6              195.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# ...

# %% [markdown]
# ### Matplotlib fun!!
# Make a random graph?
# **********

# %%
plt.plot(df["bill_length_mm"], df["bill_depth_mm"])

# %% [markdown]
# ### Cleaning Data
# Using Pandas to drop the NaN or empty cells.\
# **************

# %%
#The function dropna() in pandas creates a new data frame with any rows that have missing values removed 
#Using the argument inplace = True will replace the original data frame

df_cleaned_empty_rows = df.dropna()

# %%
df_cleaned_empty_rows
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# ...

# %%
df_cleaned_empty_rows.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 333 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            333 non-null    object
#  1   island             333 non-null    object
#  2   bill_length_mm     333 non-null    float64
#  3   bill_depth_mm      333 non-null    float64
#  4   flipper_length_mm  333 non-null    float64
#  5   body_mass_g        333 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 20.8+ KB

# %% [markdown]
# ### Using Pandas to view correlations

# %%
df_numeric = df_cleaned_empty_rows.select_dtypes(include = ('number'))
print(df_numeric)
# Out:
#      bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# 0              39.1           18.7              181.0       3750.0
# 1              39.5           17.4              186.0       3800.0
# 2              40.3           18.0              195.0       3250.0
# 4              36.7           19.3              193.0       3450.0
# 5              39.3           20.6              190.0       3650.0
# ..              ...            ...                ...          ...
# 338            47.2           13.7              214.0       4925.0
# 340            46.8           14.3              215.0       4850.0
# 341            50.4           15.7              222.0       5750.0
# 342            45.2           14.8              212.0       5200.0
# 343            49.9           16.1              213.0       5400.0
#
# [333 rows x 4 columns]

# %%
df_numeric.corr()
# Out:
#                    bill_length_mm  bill_depth_mm  flipper_length_mm  \
# bill_length_mm           1.000000      -0.228626           0.653096
# bill_depth_mm           -0.228626       1.000000          -0.577792
# flipper_length_mm        0.653096      -0.577792           1.000000
# body_mass_g              0.589451      -0.472016           0.872979
#
#                    body_mass_g
# bill_length_mm        0.589451
# bill_depth_mm        -0.472016
# flipper_length_mm     0.872979
# body_mass_g           1.000000
